# %% [markdown]
# ### Training Custom Segmentation Model -- using YOLOv8

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Specify Root Directory
# !ls '/content/gdrive/MyDrive/'
ROOT_DIR = '/content/gdrive/MyDrive/Gdansk_Airport_Data_Annotation.v4i.yolov8'

# %%
# Install Ultralytics
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.8/645.8 kB 9.3 MB/s eta 0:00:00
# ...

# %%
# Train
import os
from ultralytics import YOLO


#model = YOLO('yolov8n.pt')  # Load an official Detect model
#model = YOLO('path/to/best.pt')  # Load a custom trained model

model = YOLO('yolov8s-seg.pt')  # Load an official Segment model (Available Model Size: n/s/m/l/x)

reults = model.train(data = os.path.join(ROOT_DIR, 'data.yaml'), epochs = 100, imgsz = 640)
# Out:
# ...
# 100%|██████████| 22.8M/22.8M [00:00<00:00, 50.8MB/s]
# Ultralytics YOLOv8.0.218 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Transfer 'runs' to ROOT Directory

import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !scp -r /content/runs '/content/gdrive/MyDrive/Gdansk_Airport_Data_Annotation.v4i.yolov8'
